# %%
import _pickle as pickle

# %%
devset = pickle.load(open('../data/dev_synthetic.pkl', 'rb'))

# %%
list(devset.keys())[:10]
# Out:
# [2287, 2288, 2289, 2290, 2291, 2292, 2293, 2294, 2295, 2296]

# %%
tmp = devset[2288]
print(tmp)
# Out:
# {'topic_id': 8, 'facet_id': 'F0969', 'initial_request': 'I want to know about appraisals.', 'question': 'are you looking for a type of appraiser', 'answer': 'yes jewelry', 'conversation_context': [], 'context_id': 969}

# %%
t1 = df['topic_id'] == tmp['topic_id']
t2 = df['question'] == tmp['question']
t3 = df['answer'] == tmp['answer']
tmp_df = df[t1 & t2 & t3]
print(len(tmp_df))
print(tmp_df['facet_desc'].values[0])
print(tmp_df['topic_desc'].values[0])
# Out:
# 1
# I\'m looking for companies that appraise jewelry.
# How are home values appraised? I want to know how home appraisals are done.

# %%
import json
import pandas as pd

# %%
qulac_data = json.load(open('../data/qulac.json', 'r', encoding='utf-8'))

# %%
df = pd.DataFrame()
for key in qulac_data.keys():
    df[key] = list(qulac_data[key].values())

# %%
df[df['topic_id'] == 8]
# Out:
#       topic_id  facet_id topic_facet_id topic_facet_question_id       topic  \
# 9765         8         1            8-1                   8-1-1  appraisals
# 9766         8         1            8-1                  8-1-10  appraisals
# 9767         8         1            8-1                  8-1-11  appraisals
# 9768         8         1            8-1                  8-1-12  appraisals
# 9769         8         1            8-1                   8-1-2  appraisals
# 9770         8         1            8-1                   8-1-3  appraisals
# 9771         8         1            8-1                   8-1-4  appraisals
# 9772         8         1            8-1                   8-1-5  appraisals
# 9773         8         1            8-1                   8-1-6  appraisals
# 9774         8         1            8-1                   8-1-7  appraisals
# 9775         8         1            8-1                   8-1-8  appraisals
# 9776         8         1            8-1                   8-1-9  appraisals
# 9777         8         1            8-1                   8-1-X  appraisals
# 9778         8         2            8-2                   8-2-1  appraisals
# 9779         8         2            8-2                  8-2-10  appraisals
# 9780         8         2            8-2                  8-2-11  appraisals
# 9781         8         2            8-2                  8-2-12  appraisals
# 9782         8         2            8-2                   8-2-2  appraisals
# 9783         8         2            8-2                   8-2-3  appraisals
# 9784         8         2            8-2                   8-2-4  appraisals
# 9785         8         2            8-2                   8-2-5  appraisals
# 9786         8         2            8-2                   8-2-6  appraisals
# 9787         8         2            8-2                   8-2-7  appraisals
# 9788         8         2            8-2                   8-2-8  appraisals
# 9789         8         2            8-2                   8-2-9  appraisals
# 9790         8         2            8-2                   8-2-X  appraisals
# 9791         8         3            8-3                   8-3-1  appraisals
# 9792         8         3            8-3                  8-3-10  appraisals
# 9793         8         3            8-3                  8-3-11  appraisals
# 9794         8         3            8-3                  8-3-12  appraisals
# 9795         8         3            8-3                   8-3-2  appraisals
# 9796         8         3            8-3                   8-3-3  appraisals
# 9797         8         3            8-3                   8-3-4  appraisals
# 9798         8         3            8-3                   8-3-5  appraisals
# 9799         8         3            8-3                   8-3-6  appraisals
# 9800         8         3            8-3                   8-3-7  appraisals
# 9801         8         3            8-3                   8-3-8  appraisals
# 9802         8         3            8-3                   8-3-9  appraisals
# 9803         8         3            8-3                   8-3-X  appraisals
# 9804         8         4            8-4                   8-4-1  appraisals
# 9805         8         4            8-4                  8-4-10  appraisals
# 9806         8         4            8-4                  8-4-11  appraisals
# 9807         8         4            8-4                  8-4-12  appraisals
# 9808         8         4            8-4                   8-4-2  appraisals
# 9809         8         4            8-4                   8-4-3  appraisals
# 9810         8         4            8-4                   8-4-4  appraisals
# 9811         8         4            8-4                   8-4-5  appraisals
# 9812         8         4            8-4                   8-4-6  appraisals
# 9813         8         4            8-4                   8-4-7  appraisals
# 9814         8         4            8-4                   8-4-8  appraisals
# 9815         8         4            8-4                   8-4-9  appraisals
# 9816         8         4            8-4                   8-4-X  appraisals
#
#      topic_type facet_type                                         topic_desc  \
# 9765  ambiguous        inf  How are home values appraised? I want to know ...
# 9766  ambiguous        inf  How are home values appraised? I want to know ...
# 9767  ambiguous        inf  How are home values appraised? I want to know ...
# 9768  ambiguous        inf  How are home values appraised? I want to know ...
# 9769  ambiguous        inf  How are home values appraised? I want to know ...
# 9770  ambiguous        inf  How are home values appraised? I want to know ...
# 9771  ambiguous        inf  How are home values appraised? I want to know ...
# 9772  ambiguous        inf  How are home values appraised? I want to know ...
# 9773  ambiguous        inf  How are home values appraised? I want to know ...
# 9774  ambiguous        inf  How are home values appraised? I want to know ...
# 9775  ambiguous        inf  How are home values appraised? I want to know ...
# 9776  ambiguous        inf  How are home values appraised? I want to know ...
# 9777  ambiguous        inf  How are home values appraised? I want to know ...
# 9778  ambiguous        inf  How are home values appraised? I want to know ...
# 9779  ambiguous        inf  How are home values appraised? I want to know ...
# 9780  ambiguous        inf  How are home values appraised? I want to know ...
# 9781  ambiguous        inf  How are home values appraised? I want to know ...
# 9782  ambiguous        inf  How are home values appraised? I want to know ...
# 9783  ambiguous        inf  How are home values appraised? I want to know ...
# 9784  ambiguous        inf  How are home values appraised? I want to know ...
# 9785  ambiguous        inf  How are home values appraised? I want to know ...
# 9786  ambiguous        inf  How are home values appraised? I want to know ...
# 9787  ambiguous        inf  How are home values appraised? I want to know ...
# 9788  ambiguous        inf  How are home values appraised? I want to know ...
# 9789  ambiguous        inf  How are home values appraised? I want to know ...
# 9790  ambiguous        inf  How are home values appraised? I want to know ...
# 9791  ambiguous        inf  How are home values appraised? I want to know ...
# 9792  ambiguous        inf  How are home values appraised? I want to know ...
# 9793  ambiguous        inf  How are home values appraised? I want to know ...
# 9794  ambiguous        inf  How are home values appraised? I want to know ...
# 9795  ambiguous        inf  How are home values appraised? I want to know ...
# 9796  ambiguous        inf  How are home values appraised? I want to know ...
# 9797  ambiguous        inf  How are home values appraised? I want to know ...
# 9798  ambiguous        inf  How are home values appraised? I want to know ...
# 9799  ambiguous        inf  How are home values appraised? I want to know ...
# 9800  ambiguous        inf  How are home values appraised? I want to know ...
# 9801  ambiguous        inf  How are home values appraised? I want to know ...
# 9802  ambiguous        inf  How are home values appraised? I want to know ...
# 9803  ambiguous        inf  How are home values appraised? I want to know ...
# 9804  ambiguous        nav  How are home values appraised? I want to know ...
# 9805  ambiguous        nav  How are home values appraised? I want to know ...
# 9806  ambiguous        nav  How are home values appraised? I want to know ...
# 9807  ambiguous        nav  How are home values appraised? I want to know ...
# 9808  ambiguous        nav  How are home values appraised? I want to know ...
# 9809  ambiguous        nav  How are home values appraised? I want to know ...
# 9810  ambiguous        nav  How are home values appraised? I want to know ...
# 9811  ambiguous        nav  How are home values appraised? I want to know ...
# 9812  ambiguous        nav  How are home values appraised? I want to know ...
# 9813  ambiguous        nav  How are home values appraised? I want to know ...
# 9814  ambiguous        nav  How are home values appraised? I want to know ...
# 9815  ambiguous        nav  How are home values appraised? I want to know ...
# 9816  ambiguous        nav  How are home values appraised? I want to know ...
#
#                                              facet_desc  \
# 9765  What companies can give an appraisal of my hom...
# 9766  What companies can give an appraisal of my hom...
# 9767  What companies can give an appraisal of my hom...
# 9768  What companies can give an appraisal of my hom...
# 9769  What companies can give an appraisal of my hom...
# 9770  What companies can give an appraisal of my hom...
# 9771  What companies can give an appraisal of my hom...
# 9772  What companies can give an appraisal of my hom...
# 9773  What companies can give an appraisal of my hom...
# 9774  What companies can give an appraisal of my hom...
# 9775  What companies can give an appraisal of my hom...
# 9776  What companies can give an appraisal of my hom...
# 9777  What companies can give an appraisal of my hom...
# 9778  I\'m looking for companies that appraise jewelry.
# 9779  I\'m looking for companies that appraise jewelry.
# 9780  I\'m looking for companies that appraise jewelry.
# 9781  I\'m looking for companies that appraise jewelry.
# 9782  I\'m looking for companies that appraise jewelry.
# 9783  I\'m looking for companies that appraise jewelry.
# 9784  I\'m looking for companies that appraise jewelry.
# 9785  I\'m looking for companies that appraise jewelry.
# 9786  I\'m looking for companies that appraise jewelry.
# 9787  I\'m looking for companies that appraise jewelry.
# 9788  I\'m looking for companies that appraise jewelry.
# 9789  I\'m looking for companies that appraise jewelry.
# 9790  I\'m looking for companies that appraise jewelry.
# 9791  Find examples of employee performance appraisals.
# 9792  Find examples of employee performance appraisals.
# 9793  Find examples of employee performance appraisals.
# 9794  Find examples of employee performance appraisals.
# 9795  Find examples of employee performance appraisals.
# 9796  Find examples of employee performance appraisals.
# 9797  Find examples of employee performance appraisals.
# 9798  Find examples of employee performance appraisals.
# 9799  Find examples of employee performance appraisals.
# 9800  Find examples of employee performance appraisals.
# 9801  Find examples of employee performance appraisals.
# 9802  Find examples of employee performance appraisals.
# 9803  Find examples of employee performance appraisals.
# 9804  I\'m looking for web sites that do antique app...
# 9805  I\'m looking for web sites that do antique app...
# 9806  I\'m looking for web sites that do antique app...
# 9807  I\'m looking for web sites that do antique app...
# 9808  I\'m looking for web sites that do antique app...
# 9809  I\'m looking for web sites that do antique app...
# 9810  I\'m looking for web sites that do antique app...
# 9811  I\'m looking for web sites that do antique app...
# 9812  I\'m looking for web sites that do antique app...
# 9813  I\'m looking for web sites that do antique app...
# 9814  I\'m looking for web sites that do antique app...
# 9815  I\'m looking for web sites that do antique app...
# 9816  I\'m looking for web sites that do antique app...
#
#                                                question  \
# 9765            are you looking for a type of appraiser
# 9766         would you like to find appraisers near you
# 9767  would you like to see a price range for apprai...
# 9768  would you like to see the definitions of appra...
# 9769   are you looking for appraisal companies near you
# 9770                are you offering appraisal services
# 9771                       do you need a home appraisal
# 9772                   do you need an antique apprasied
# 9773       do you want to know the cost of an appraisal
# 9774                         what do you need appraised
# 9775         what kind of appraisal are you looking for
# 9776  what type of appraisals do you need informatio...
# 9777
# 9778            are you looking for a type of appraiser
# 9779         would you like to find appraisers near you
# 9780  would you like to see a price range for apprai...
# 9781  would you like to see the definitions of appra...
# 9782   are you looking for appraisal companies near you
# 9783                are you offering appraisal services
# 9784                       do you need a home appraisal
# 9785                   do you need an antique apprasied
# 9786       do you want to know the cost of an appraisal
# 9787                         what do you need appraised
# 9788         what kind of appraisal are you looking for
# 9789  what type of appraisals do you need informatio...
# 9790
# 9791            are you looking for a type of appraiser
# 9792         would you like to find appraisers near you
# 9793  would you like to see a price range for apprai...
# 9794  would you like to see the definitions of appra...
# 9795   are you looking for appraisal companies near you
# 9796                are you offering appraisal services
# 9797                       do you need a home appraisal
# 9798                   do you need an antique apprasied
# 9799       do you want to know the cost of an appraisal
# 9800                         what do you need appraised
# 9801         what kind of appraisal are you looking for
# 9802  what type of appraisals do you need informatio...
# 9803
# 9804            are you looking for a type of appraiser
# 9805         would you like to find appraisers near you
# 9806  would you like to see a price range for apprai...
# 9807  would you like to see the definitions of appra...
# 9808   are you looking for appraisal companies near you
# 9809                are you offering appraisal services
# 9810                       do you need a home appraisal
# 9811                   do you need an antique apprasied
# 9812       do you want to know the cost of an appraisal
# 9813                         what do you need appraised
# 9814         what kind of appraisal are you looking for
# 9815  what type of appraisals do you need informatio...
# 9816
#
#                                                  answer
# 9765  im looking for nearby companies that do home a...
# 9766                                                yes
# 9767  no i want to know what companies will appraise...
# 9768                           no i want the appraisers
# 9769                                                yes
# 9770                                                 no
# 9771                        yes i need a home appraisal
# 9772                        no i want my home apprasied
# 9773  no i want to know the compalnies that can give...
# 9774                                            my home
# 9775    i am looking for an appraisal of my homes value
# 9776     i need information about home value appraisals
# 9777
# 9778                                        yes jewelry
# 9779                                                yes
# 9780  no i am looking for the companies that will ap...
# 9781                                                 no
# 9782       i am looking for jewlery appraisal companies
# 9783    i want to know which companies appraise jewelry
# 9784  no i need a list of companies thatr appraise j...
# 9785                       yes i need jewelry appraised
# 9786   i need a list of companies that appraise jewelry
# 9787  i dont need anything appraised i am just looki...
# 9788                                a jewelry appraisal
# 9789                                      about jewelry
# 9790
# 9791  no i want information about employee performan...
# 9792  no i am looking for examples of employee perfo...
# 9793                                                 no
# 9794                 no examples of employee appraisals
# 9795  no i am looking for employee performance appra...
# 9796  no i am onterested in seeing examples of emplo...
# 9797  no i need an example of emplyee performance ap...
# 9798            no im interested in employee appraisals
# 9799  no can you give me some examples of employee p...
# 9800        nothing im asking about employee appraisals
# 9801  i am looking for employee performance appraisa...
# 9802                    employee performance appraisals
# 9803
# 9804                                       yes antiques
# 9805    no i am looking for websites that do appraisals
# 9806                        no im looking for web sites
# 9807                  no looking for antique appraisals
# 9808  no im looking for websites that do antique app...
# 9809                                                 no
# 9810  no i am looking for an online antique appraisa...
# 9811                                                yes
# 9812      no im looking for websites that do appraisals
# 9813                 i need an antique appraised online
# 9814                  im looking for antique appraisals
# 9815        i need information about antique appraisals
# 9816

# %%
err_keys = []
for key in devset.keys():
    t1 = df['topic_id'] == devset[key]['topic_id']
    t2 = df['question'] == devset[key]['question']
    t3 = df['answer'] == devset[key]['answer']
    tmp_df = df[t1 & t2 & t3]
    if len(tmp_df) < 1:
        err_keys.append(key)
        continue
    devset[key]['topic_desc'] = tmp_df['topic_desc'].values[0]
    devset[key]['facet_desc'] = tmp_df['facet_desc'].values[0]

# %%
len(err_keys), len(devset.keys())
# Out:
# (8285, 182435)

# %%
devset[2288]
# Out:
# {'topic_id': 8,
#  'facet_id': 'F0969',
#  'initial_request': 'I want to know about appraisals.',
#  'question': 'are you looking for a type of appraiser',
#  'answer': 'yes jewelry',
#  'conversation_context': [],
#  'context_id': 969,
#  'topic_desc': 'How are home values appraised? I want to know how home appraisals are done.',
#  'facet_desc': "I\\'m looking for companies that appraise jewelry."}

# %%
tidfid2data = {}
for key, value in devset.items():
    newkey = '{}-{}'.format(value['topic_id'], value['facet_id'])
    if newkey not in tidfid2data:
        tidfid2data[newkey] = []
    tidfid2data[newkey].append(key)

# %%
len(tidfid2data)
# Out:
# 158

# %%
tidfid2data.keys()
# Out:
# dict_keys(['8-F0968', '8-F0969', '8-F0970', '8-F0971', '18-F0316', '18-F0317', '18-F0318', '18-F0319', '18-F0320', '20-F0395', '20-F0396', '20-F0397', '20-F0398', '24-F0539', '24-F0540', '24-F0541', '24-F0542', '25-F0572', '25-F0573', '25-F0574', '27-F0630', '27-F0631', '27-F0632', '27-F0633', '27-F0634', '35-F0774', '35-F0775', '35-F0776', '35-F0777', '35-F0778', '35-F0779', '37-F0782', '37-F0783', '37-F0784', '37-F0785', '44-F0813', '44-F0814', '44-F0815', '44-F0816', '44-F0817', '45-F0818', '45-F0819', '45-F0820', '51-F0841', '51-F0842', '51-F0843', '51-F0844', '51-F0845', '71-F0932', '71-F0933', '71-F0934', '71-F0935', '74-F0943', '74-F0944', '74-F0945', '79-F0964', '79-F0965', '79-F0966', '79-F0967', '83-F0981', '83-F0982', '83-F0983', '85-F0987', '85-F0988', '85-F0989', '85-F0990', '101-F0010', '101-F0011', '101-F0012', '101-F0013', '106-F0028', '106-F0029', '106-F0030', '107-F0031', '107-F0032', '107-F0033', '107-F0034', '107-F0035', '107-F0036', '110-F0050', '110-F0051', '110-F0052', '114-F0063', '114-F0064', '114-F0065', '118-F0078', '118-F0079', '118-F0080', '118-F0081', '123-F0100', '123-F0101', '123-F0102', '126-F0110', '126-F0111', '128-F0114', '128-F0115', '128-F0116', '133-F0134', '133-F0135', '133-F0136', '133-F0137', '133-F0138', '139-F0156', '139-F0157', '139-F0158', '142-F0170', '142-F0171', '142-F0172', '152-F0201', '152-F0202', '152-F0203', '152-F0204', '164-F0254', '164-F0255', '164-F0256', '164-F0257', '165-F0258', '165-F0259', '165-F0260', '165-F0261', '169-F0268', '169-F0269', '169-F0270', '169-F0271', '174-F0293', '174-F0294', '174-F0295', '174-F0296', '174-F0297', '190-F0359', '190-F0360', '190-F0361', '191-F0362', '191-F0363', '191-F0364', '191-F0365', '193-F0369', '193-F0370', '193-F0371', '195-F0375', '195-F0376', '195-F0377', '195-F0378', '200-F0399', '200-F0400', '200-F0401', '200-F0402', '214-F0466', '219-F0481', '229-F0511', '250-F0575', '252-F0577', '256-F0594', '262-F0619', '283-F0693', '287-F0699', '292-F0728', '293-F0729'])

# %%
tidfid2data['8-F0968']
# Out:
# [2287,
#  2291,
#  2295,
#  2299,
#  2303,
#  2307,
#  2311,
#  2315,
#  2319,
#  2323,
#  2327,
#  2331,
#  15755,
#  15759,
#  15763,
#  15767,
#  15771,
#  15775,
#  15779,
#  15783,
#  15787,
#  15791,
#  15795,
#  15799,
#  15803,
#  15807,
#  15811,
#  15815,
#  15819,
#  15823,
#  15827,
#  15831,
#  15835,
#  15839,
#  15843,
#  15847,
#  15851,
#  15855,
#  15859,
#  15863,
#  15867,
#  15871,
#  15875,
#  15879,
#  15883,
#  15887,
#  15891,
#  15895,
#  15899,
#  15903,
#  15907,
#  15911,
#  15915,
#  15919,
#  15923,
#  15927,
#  15931,
#  15935,
#  15939,
#  15943,
#  15947,
#  15951,
#  15955,
#  15959,
#  15963,
#  15967,
#  15971,
#  15975,
#  15979,
#  15983,
#  15987,
#  15991,
#  15995,
#  15999,
#  16003,
#  16007,
#  16011,
#  16015,
#  16019,
#  16023,
#  16027,
#  16031,
#  16035,
#  16039,
#  16043,
#  16047,
#  16051,
#  16055,
#  16059,
#  16063,
#  16067,
#  16071,
#  16075,
#  16079,
#  16083,
#  16087,
#  16091,
#  16095,
#  16099,
#  16103,
#  16107,
#  16111,
#  16115,
#  16119,
#  16123,
#  16127,
#  16131,
#  16135,
#  16139,
#  16143,
#  16147,
#  16151,
#  16155,
#  16159,
#  16163,
#  16167,
#  16171,
#  16175,
#  16179,
#  16183,
#  16187,
#  16191,
#  16195,
#  16199,
#  16203,
#  16207,
#  16211,
#  16215,
#  16219,
#  16223,
#  16227,
#  16231,
#  16235,
#  16239,
#  16243,
#  16247,
#  16251,
#  16255,
#  16259,
#  16263,
#  16267,
#  16271,
#  16275,
#  16279,
#  162160,
#  162164,
#  162168,
#  162172,
#  162176,
#  162180,
#  162184,
#  162188,
#  162192,
#  162196,
#  162200,
#  162204,
#  162208,
#  162212,
#  162216,
#  162220,
#  162224,
#  162228,
#  162232,
#  162236,
#  162240,
#  162244,
#  162248,
#  162252,
#  162256,
#  162260,
#  162264,
#  162268,
#  162272,
#  162276,
#  162280,
#  162284,
#  162288,
#  162292,
#  162296,
#  162300,
#  162304,
#  162308,
#  162312,
#  162316,
#  162320,
#  162324,
#  162328,
#  162332,
#  162336,
#  162340,
#  162344,
#  162348,
#  162352,
#  162356,
#  162360,
#  162364,
#  162368,
#  162372,
#  162376,
#  162380,
#  162384,
#  162388,
#  162392,
#  162396,
#  162400,
#  162404,
#  162408,
#  162412,
#  162416,
#  162420,
#  162424,
#  162428,
#  162432,
#  162436,
#  162440,
#  162444,
#  162448,
#  162452,
#  162456,
#  162460,
#  162464,
#  162468,
#  162472,
#  162476,
#  162480,
#  162484,
#  162488,
#  162492,
#  162496,
#  162500,
#  162504,
#  162508,
#  162512,
#  162516,
#  162520,
#  162524,
#  162528,
#  162532,
#  162536,
#  162540,
#  162544,
#  162548,
#  162552,
#  162556,
#  162560,
#  162564,
#  162568,
#  162572,
#  162576,
#  162580,
#  162584,
#  162588,
#  162592,
#  162596,
#  162600,
#  162604,
#  162608,
#  162612,
#  162616,
#  162620,
#  162624,
#  162628,
#  162632,
#  162636,
#  162640,
#  162644,
#  162648,
#  162652,
#  162656,
#  162660,
#  162664,
#  162668,
#  162672,
#  162676,
#  162680,
#  162684,
#  162688,
#  162692,
#  162696,
#  162700,
#  162704,
#  162708,
#  162712,
#  162716,
#  162720,
#  162724,
#  162728,
#  162732,
#  162736,
#  162740,
#  162744,
#  162748,
#  162752,
#  162756,
#  162760,
#  162764,
#  162768,
#  162772,
#  162776,
#  162780,
#  162784,
#  162788,
#  162792,
#  162796,
#  162800,
#  162804,
#  162808,
#  162812,
#  162816,
#  162820,
#  162824,
#  162828,
#  162832,
#  162836,
#  162840,
#  162844,
#  162848,
#  162852,
#  162856,
#  162860,
#  162864,
#  162868,
#  162872,
#  162876,
#  162880,
#  162884,
#  162888,
#  162892,
#  162896,
#  162900,
#  162904,
#  162908,
#  162912,
#  162916,
#  162920,
#  162924,
#  162928,
#  162932,
#  162936,
#  162940,
#  162944,
#  162948,
#  162952,
#  162956,
#  162960,
#  162964,
#  162968,
#  162972,
#  162976,
#  162980,
#  162984,
#  162988,
#  162992,
#  162996,
#  163000,
#  163004,
#  163008,
#  163012,
#  163016,
#  163020,
#  163024,
#  163028,
#  163032,
#  163036,
#  163040,
#  163044,
#  163048,
#  163052,
#  163056,
#  163060,
#  163064,
#  163068,
#  163072,
#  163076,
#  163080,
#  163084,
#  163088,
#  163092,
#  163096,
#  163100,
#  163104,
#  163108,
#  163112,
#  163116,
#  163120,
#  163124,
#  163128,
#  163132,
#  163136,
#  163140,
#  163144,
#  163148,
#  163152,
#  163156,
#  163160,
#  163164,
#  163168,
#  163172,
#  163176,
#  163180,
#  163184,
#  163188,
#  163192,
#  163196,
#  163200,
#  163204,
#  163208,
#  163212,
#  163216,
#  163220,
#  163224,
#  163228,
#  163232,
#  163236,
#  163240,
#  163244,
#  163248,
#  163252,
#  163256,
#  163260,
#  163264,
#  163268,
#  163272,
#  163276,
#  163280,
#  163284,
#  163288,
#  163292,
#  163296,
#  163300,
#  163304,
#  163308,
#  163312,
#  163316,
#  163320,
#  163324,
#  163328,
#  163332,
#  163336,
#  163340,
#  163344,
#  163348,
#  163352,
#  163356,
#  163360,
#  163364,
#  163368,
#  163372,
#  163376,
#  163380,
#  163384,
#  163388,
#  163392,
#  163396,
#  163400,
#  163404,
#  163408,
#  163412,
#  163416,
#  163420,
#  163424,
#  163428,
#  163432,
#  163436,
#  163440,
#  163444,
#  163448,
#  163452,
#  163456,
#  163460,
#  163464,
#  163468,
#  163472,
#  163476,
#  163480,
#  163484,
#  163488,
#  163492,
#  163496,
#  163500,
#  163504,
#  163508,
#  163512,
#  163516,
#  163520,
#  163524,
#  163528,
#  163532,
#  163536,
#  163540,
#  163544,
#  163548,
#  163552,
#  163556,
#  163560,
#  163564,
#  163568,
#  163572,
#  163576,
#  163580,
#  163584,
#  163588,
#  163592,
#  163596,
#  163600,
#  163604,
#  163608,
#  163612,
#  163616,
#  163620,
#  163624,
#  163628,
#  163632,
#  163636,
#  163640,
#  163644,
#  163648,
#  163652,
#  163656,
#  163660,
#  163664,
#  163668,
#  163672,
#  163676,
#  163680,
#  163684,
#  163688,
#  163692,
#  163696,
#  163700,
#  163704,
#  163708,
#  163712,
#  163716,
#  163720,
#  163724,
#  163728,
#  163732,
#  163736,
#  163740,
#  163744,
#  163748,
#  163752,
#  163756,
#  163760,
#  163764,
#  163768,
#  163772,
#  163776,
#  163780,
#  163784,
#  163788,
#  163792,
#  163796,
#  163800,
#  163804,
#  163808,
#  163812,
#  163816,
#  163820,
#  163824,
#  163828,
#  163832,
#  163836,
#  163840,
#  163844,
#  163848,
#  163852,
#  163856,
#  163860,
#  163864,
#  163868,
#  163872,
#  163876,
#  163880,
#  163884,
#  163888,
#  163892,
#  163896,
#  163900,
#  163904,
#  163908,
#  163912,
#  163916,
#  163920,
#  163924,
#  163928,
#  163932,
#  163936,
#  163940,
#  163944,
#  163948,
#  163952,
#  163956,
#  163960,
#  163964,
#  163968,
#  163972,
#  163976,
#  163980,
#  163984,
#  163988,
#  163992,
#  163996,
#  164000,
#  164004,
#  164008,
#  164012,
#  164016,
#  164020,
#  164024,
#  164028,
#  164032,
#  164036,
#  164040,
#  164044,
#  164048,
#  164052,
#  164056,
#  164060,
#  164064,
#  164068,
#  164072,
#  164076,
#  164080,
#  164084,
#  164088,
#  164092,
#  164096,
#  164100,
#  164104,
#  164108,
#  164112,
#  164116,
#  164120,
#  164124,
#  164128,
#  164132,
#  164136,
#  164140,
#  164144,
#  164148,
#  164152,
#  164156,
#  164160,
#  164164,
#  164168,
#  164172,
#  164176,
#  164180,
#  164184,
#  164188,
#  164192,
#  164196,
#  164200,
#  164204,
#  164208,
#  164212,
#  164216,
#  164220,
#  164224,
#  164228,
#  164232,
#  164236,
#  164240,
#  164244,
#  164248,
#  164252,
#  164256,
#  164260,
#  164264,
#  164268,
#  164272,
#  164276,
#  164280,
#  164284,
#  164288,
#  164292,
#  164296,
#  164300,
#  164304,
#  164308,
#  164312,
#  164316,
#  164320,
#  164324,
#  164328,
#  164332,
#  164336,
#  164340,
#  164344,
#  164348,
#  164352,
#  164356,
#  164360,
#  164364,
#  164368,
#  164372,
#  164376,
#  164380,
#  164384,
#  164388,
#  164392,
#  164396,
#  164400,
#  164404,
#  164408,
#  164412,
#  164416,
#  164420,
#  164424,
#  164428,
#  164432,
#  164436,
#  164440,
#  164444,
#  164448,
#  164452,
#  164456,
#  164460,
#  164464,
#  164468,
#  164472,
#  164476,
#  164480,
#  164484,
#  164488,
#  164492,
#  164496,
#  164500,
#  164504,
#  164508,
#  164512,
#  164516,
#  164520,
#  164524,
#  164528,
#  164532,
#  164536,
#  164540,
#  164544,
#  164548,
#  164552,
#  164556,
#  164560,
#  164564,
#  164568,
#  164572,
#  164576,
#  164580,
#  164584,
#  164588,
#  164592,
#  164596,
#  164600,
#  164604,
#  164608,
#  164612,
#  164616,
#  164620,
#  164624,
#  164628,
#  164632,
#  164636,
#  164640,
#  164644,
#  164648,
#  164652,
#  164656,
#  164660,
#  164664,
#  164668,
#  164672,
#  164676,
#  164680,
#  164684,
#  164688,
#  164692,
#  164696,
#  164700,
#  164704,
#  164708,
#  164712,
#  164716,
#  164720,
#  164724,
#  164728,
#  164732,
#  164736,
#  164740,
#  164744,
#  164748,
#  164752,
#  164756,
#  164760,
#  164764,
#  164768,
#  164772,
#  164776,
#  164780,
#  164784,
#  164788,
#  164792,
#  164796]

# %%
devset[2287]
# Out:
# {'topic_id': 8,
#  'facet_id': 'F0968',
#  'initial_request': 'I want to know about appraisals.',
#  'question': 'are you looking for a type of appraiser',
#  'answer': 'im looking for nearby companies that do home appraisals',
#  'conversation_context': [],
#  'context_id': 968,
#  'topic_desc': 'How are home values appraised? I want to know how home appraisals are done.',
#  'facet_desc': "What companies can give an appraisal of my home\\'s value?"}

# %%
devset[2291]
# Out:
# {'topic_id': 8,
#  'facet_id': 'F0968',
#  'initial_request': 'I want to know about appraisals.',
#  'question': 'are you looking for appraisal companies near you',
#  'answer': 'yes',
#  'conversation_context': [],
#  'context_id': 968,
#  'topic_desc': 'How are home values appraised? I want to know how home appraisals are done.',
#  'facet_desc': "What companies can give an appraisal of my home\\'s value?"}

# %%
devset[2323]
# Out:
# {'topic_id': 8,
#  'facet_id': 'F0968',
#  'initial_request': 'I want to know about appraisals.',
#  'question': 'would you like to find appraisers near you',
#  'answer': 'yes',
#  'conversation_context': [],
#  'context_id': 968,
#  'topic_desc': 'How are home values appraised? I want to know how home appraisals are done.',
#  'facet_desc': "What companies can give an appraisal of my home\\'s value?"}

# %%
import pandas as pd
from rank_bm25 import BM25Okapi
import nltk
import pickle
from nltk.stem.porter import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')

def stem_tokenize(text, remove_stopwords=True):
  stemmer = PorterStemmer()
  tokens = [word for sent in nltk.sent_tokenize(text) \
                                      for word in nltk.word_tokenize(sent)]
  tokens = [word for word in tokens if word not in \
          nltk.corpus.stopwords.words('english')]
  return [stemmer.stem(word) for word in tokens]
# Out:
# [nltk_data] Downloading package punkt to /Users/moli/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/moli/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Files paths

multi_turn_request_file_path = '../data/dev_synthetic.pkl'
question_bank_path = '../data/question_bank.tsv'
run_file_path = '../sample_runs/dev_bm25_multi_turn'

# %%
# Reads files and build bm25 corpus (index)
with open(multi_turn_request_file_path, 'rb') as fi:
    dev = pickle.load(fi)
question_bank = pd.read_csv(question_bank_path, sep='\t').fillna('')

question_bank['tokenized_question_list'] = question_bank['question'].map(stem_tokenize)
question_bank['tokenized_question_str'] = question_bank['tokenized_question_list'].map(lambda x: ' '.join(x))

bm25_corpus = question_bank['tokenized_question_list'].tolist()
bm25 = BM25Okapi(bm25_corpus)

# %%
# Reads the dev file and create the context_dict to make predictions
context_dict = dict()
for rec_id in dev:
    ctx_id = dev[rec_id]['context_id']
    if ctx_id not in context_dict:
        context_dict[ctx_id] = {'initial_request': dev[rec_id]['initial_request'],
                                'conversation_context': dev[rec_id]['conversation_context']}

# %%
# Runs bm25 for every query and stores output in file.

def build_query(context_info):
    query_str = context_info['initial_request']
    for ctx in context_info['conversation_context']:
        query_str += ctx['question'] + ' ' + ctx['answer']
    return query_str

def select_no_duplicate_questions(bm25_q_list, conv_context):
    prev_questions = [x['question'] for x in conv_context]
    bm25_preds = question_bank.set_index('tokenized_question_str').loc[bm25_q_list, 'question'].tolist()
    pred_list = []
    for q in bm25_preds:
        if q not in prev_questions:
            pred_list.append(q)
    return pred_list

with open(run_file_path, 'w') as fo:
  for ctx_id in context_dict:
    query = build_query(context_dict[ctx_id])
    bm25_ranked_list = bm25.get_top_n(stem_tokenize(query, True), 
                                    bm25_corpus,
                                    n=5)
    bm25_q_list = [' '.join(sent) for sent in bm25_ranked_list]
    preds = select_no_duplicate_questions(bm25_q_list, context_dict[ctx_id]['conversation_context'])
    for i, qid in enumerate(preds):
        fo.write('{} 0 "{}" {} {} bm25_multi_turn\n'.format(ctx_id, qid, i, len(preds)-i))
        break # we write only one result per context.

# %%
! python clariq_eval_tool.py    --eval_task document_relevance\
                                --data_dir ../data/ \
                                --multi_turn \
                                --experiment_type dev \
                                --run_file {run_file_path} #\
                                # --out_file {run_file_path}.eval
# Out:
# NDCG1: 0.21898645957785742
# NDCG3: 0.201618860054938
# NDCG5: 0.19652670322787674
# NDCG10: 0.1856817702651898
# NDCG20: 0.17112798502504814
# P1: 0.2747245453338643
# P3: 0.2423116067082614
# P5: 0.2295632550112837
# P10: 0.2003849727864065
# P20: 0.15768949953537767
# MRR100: 0.35986740195719213
