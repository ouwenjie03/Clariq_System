# %%
import _pickle as pickle
import pandas as pd
import numpy as np
import re

# %%
train_eval = pickle.load(open('../data/single_turn_train_eval.pkl', 'rb'))

# %%
train_eval['MRR100']['F0001']
# Out:
# {'Q00384': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q03442': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q03402': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q03725': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q00769': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q01286': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q02152': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q02527': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q02950': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q03023': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q03071': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q03351': {'no_answer': 0.0, 'with_answer': 0.0},
#  'Q00001': {'with_answer': 0.03225806451612903,
#   'no_answer': 0.03225806451612903},
#  'MAX': {'with_answer': 0.03225806451612903, 'no_answer': 0.03225806451612903},
#  'MIN': {'with_answer': 0.0, 'no_answer': 0.0}}

# %%
trainset = pd.read_csv('../data/train.tsv', sep='\t')
devset = pd.read_csv('../data/dev.tsv', sep='\t')

# %%
def get_answer_scores(trainset):
    score_keys = list(train_eval.keys())
    answer_scores = []
    for fid, qid, question, answer in trainset[['facet_id', 'question_id', 'question', 'answer']].values:
        if pd.isna(answer):
            continue
        scores = {}
        for k in score_keys:
            if fid in train_eval[k] and qid in train_eval[k][fid]:
                scores[k] = train_eval[k][fid][qid]['with_answer']
            else:
                scores[k] = 0.
        answer_scores.append((question, answer, scores, np.mean([_v for _v in scores.values()])))
    return answer_scores

# %%
train_answer_scores = get_answer_scores(trainset)
print(len(train_answer_scores), len([_a for _a in train_answer_scores if _a[-1] == 0]))

buckets = [0 for _ in range(11)]
for a in train_answer_scores:
    if a[-1] == 0:
        i = 0
    else:
        i = int(a[-1] * 10)
        i = i if i < 10 else 9
        i += 1
    buckets[i] += 1
print(buckets)
# Out:
# 8566 2469
# [2469, 2561, 775, 466, 403, 536, 394, 369, 273, 176, 144]

# %%
dev_answer_scores = get_answer_scores(devset)
len(dev_answer_scores), len([_a for _a in dev_answer_scores if _a[-1] == 0])

buckets = [0 for _ in range(11)]
for a in dev_answer_scores:
    if a[-1] == 0:
        i = 0
    else:
        i = int(a[-1] * 10)
        i = i if i < 10 else 9
        i += 1
    buckets[i] += 1
print(buckets)
# Out:
# [608, 680, 161, 107, 73, 167, 121, 77, 79, 55, 33]

# %%
def build_datas(answer_scores):
    datas = []
    for a in answer_scores:
        if a[-1] == 0:
            datas.append((a[0], a[1], 0))
        elif a[-1] < 0.2:
            datas.append((a[0], a[1], 1))
        else:
            datas.append((a[0], a[1], 2))
    return datas

# %%
train_answer_datas = build_datas(train_answer_scores)
print(len([_d for _d in train_answer_datas if _d[-1] == 0]))
print(len([_d for _d in train_answer_datas if _d[-1] == 1]))
print(len([_d for _d in train_answer_datas if _d[-1] == 2]))
# Out:
# 2469
# 3336
# 2761

# %%
dev_answer_datas = build_datas(dev_answer_scores)
print(len([_d for _d in dev_answer_datas if _d[-1] == 0]))
print(len([_d for _d in dev_answer_datas if _d[-1] == 1]))
print(len([_d for _d in dev_answer_datas if _d[-1] == 2]))
# Out:
# 608
# 841
# 712

# %%
pickle.dump(train_answer_datas, open('../data/answer_datas/train.pkl', 'wb'))
pickle.dump(dev_answer_datas, open('../data/answer_datas/dev.pkl', 'wb'))

# %%
train_answer_scores
# Out:
# [('are you interested in seeing barack obamas family',
#   'yes am interested in obamas family',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like to know barack obamas geneology',
#   'yes i want to know who made up his family',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like to know about obamas ancestors',
#   'yes this is what am looking for',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like to know who is currently alive from president obamas family tree',
#   'no find the barack obamas family tree time magazine photo essay',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for biological information on his family',
#   'no i need the specific time magazine article titled barack obamas family tree',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you referring to the time magazine essay',
#   'yes please locate the photo essay',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want to know more about obamas parents',
#   'yes',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('how many generations would you like me to list from president obamas family tree',
#   'none',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('what would you like to know about obamas heritage',
#   'no i am looking for the time magazine article titled barack obamas family tree',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('which family members of obama are you interested in learning more about',
#   'no i just want to see the barack obamas family tree photo essay on time magazine',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('which specific details would you like to learn about obamas heritage',
#   'im looking for the time magazine photo essay called barack obamas family tree',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like to hear about president obamas family tree',
#   'i would like the barack obama family tree in the time magazine photo essay',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you interested in seeing barack obamas family',
#   'no i want to know where obamas parents and grandparents came from',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.7653606369886218,
#    'NDCG5': 0.6843515475204854,
#    'NDCG10': 0.5077181160122075,
#    'NDCG20': 0.43630951506854154,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.4,
#    'P20': 0.35,
#    'MRR100': 1.0},
#   0.6736733165687748),
#  ('would you like to know barack obamas geneology',
#   'yes i want to know where obamas parents and grandparents came from',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.7039180890341348,
#    'NDCG5': 0.6548086577531307,
#    'NDCG10': 0.5606114592078374,
#    'NDCG20': 0.4377776859895756,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.5,
#    'P20': 0.35,
#    'MRR100': 1.0},
#   0.6794347780592132),
#  ('would you like to know about obamas ancestors',
#   'yes particualarly information about his parents and grandparents',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.7039180890341348,
#    'NDCG5': 0.6548086577531307,
#    'NDCG10': 0.4249260138166711,
#    'NDCG20': 0.27423337482851784,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.3,
#    'P20': 0.15,
#    'MRR100': 1.0},
#   0.6158684365544654),
#  ('would you like to know who is currently alive from president obamas family tree',
#   'no i want to know where his parents and grandparents are from',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.7039180890341348,
#    'NDCG5': 0.6548086577531307,
#    'NDCG10': 0.4249260138166711,
#    'NDCG20': 0.27423337482851784,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.3,
#    'P20': 0.15,
#    'MRR100': 1.0},
#   0.6158684365544654),
#  ('are you looking for biological information on his family',
#   'yes specifically information about his parents and grandparents',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.46927872602275655,
#    'NDCG5': 0.3391602052736161,
#    'NDCG10': 0.2200917662980802,
#    'NDCG20': 0.14204003963365733,
#    'P1': 1.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 1.0},
#   0.4412640064146767),
#  ('are you referring to the time magazine essay',
#   'no i need information about where obamas parents and grandparents are from',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.7653606369886218,
#    'NDCG5': 0.6843515475204854,
#    'NDCG10': 0.4440973278132557,
#    'NDCG20': 0.43114887559769244,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.3,
#    'P20': 0.35,
#    'MRR100': 1.0},
#   0.6583295504169746),
#  ('do you want to know more about obamas parents',
#   'no i would like to know more about obamas grand parrents',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.5307212739772434,
#    'NDCG5': 0.5147714448836773,
#    'NDCG10': 0.3340514446642156,
#    'NDCG20': 0.2825138379157175,
#    'P1': 0.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.3,
#    'P20': 0.25,
#    'MRR100': 0.5},
#   0.3617022425552291),
#  ('how many generations would you like me to list from president obamas family tree',
#   'two generations obamas parents and grandparents',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.7039180890341348,
#    'NDCG5': 0.6548086577531307,
#    'NDCG10': 0.4249260138166711,
#    'NDCG20': 0.4142873368090531,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.3,
#    'P20': 0.35,
#    'MRR100': 1.0},
#   0.6467824330981505),
#  ('what would you like to know about obamas heritage',
#   'yes i want information on obamas heritage',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.5307212739772434,
#    'NDCG5': 0.38356636737133554,
#    'NDCG10': 0.32730659600126993,
#    'NDCG20': 0.27700877252782247,
#    'P1': 0.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.4,
#    'P10': 0.3,
#    'P20': 0.25,
#    'MRR100': 0.5},
#   0.3304790615040307),
#  ('which family members of obama are you interested in learning more about',
#   'i am interested in learning about where obamas parents and grandparents came from',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.46927872602275655,
#    'NDCG5': 0.48522855511632257,
#    'NDCG10': 0.38824405276699103,
#    'NDCG20': 0.3545314661445594,
#    'P1': 1.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.4,
#    'P10': 0.3,
#    'P20': 0.3,
#    'MRR100': 1.0},
#   0.5482378303076328),
#  ('which specific details would you like to learn about obamas heritage',
#   'where they were born at',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.5307212739772434,
#    'NDCG5': 0.5147714448836773,
#    'NDCG10': 0.46392645631755636,
#    'NDCG20': 0.4041888885637639,
#    'P1': 0.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.5,
#    'P20': 0.4,
#    'MRR100': 0.5},
#   0.41638861185535525),
#  ('would you like to hear about president obamas family tree',
#   'yes but focus on his parents and grandparents',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.7039180890341348,
#    'NDCG5': 0.6548086577531307,
#    'NDCG10': 0.5579780239524,
#    'NDCG20': 0.43447203757176284,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.5,
#    'P20': 0.35,
#    'MRR100': 1.0},
#   0.6788948613616449),
#  ('are you interested in seeing barack obamas family',
#   'yes please find me information on barack obamas mother',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.46927872602275655,
#    'NDCG5': 0.6164336326286644,
#    'NDCG10': 0.47842151728792737,
#    'NDCG20': 0.3795018678094503,
#    'P1': 1.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.6,
#    'P10': 0.4,
#    'P20': 0.3,
#    'MRR100': 1.0},
#   0.5979062797347393),
#  ('would you like to know barack obamas geneology',
#   'i would like biographical information on his mother',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.5307212739772434,
#    'NDCG5': 0.5147714448836773,
#    'NDCG10': 0.40741536676357565,
#    'NDCG20': 0.3341821837030036,
#    'P1': 0.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.4,
#    'P20': 0.3,
#    'MRR100': 0.5},
#   0.3867051759994697),
#  ('would you like to know about obamas ancestors',
#   'yes specifically his mother',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.5307212739772434,
#    'NDCG5': 0.38356636737133554,
#    'NDCG10': 0.32730659600126993,
#    'NDCG20': 0.24598316269365772,
#    'P1': 0.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.4,
#    'P10': 0.3,
#    'P20': 0.2,
#    'MRR100': 0.5},
#   0.3231130969736521),
#  ('would you like to know who is currently alive from president obamas family tree',
#   'no i would like baracks mothers biological information',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.5307212739772434,
#    'NDCG5': 0.5147714448836773,
#    'NDCG10': 0.39767223286316733,
#    'NDCG20': 0.32628971599381157,
#    'P1': 0.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.4,
#    'P20': 0.3,
#    'MRR100': 0.5},
#   0.385101939489506),
#  ('are you looking for biological information on his family',
#   'yes i am specifically looking for biographical information about his morther',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.2960819109658653,
#    'NDCG5': 0.21398626473452753,
#    'NDCG10': 0.13886244387355454,
#    'NDCG20': 0.08961728720334346,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.5},
#   0.1747164763736931),
#  ('are you referring to the time magazine essay',
#   'no i just want bio information about barack obamas mother',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.46927872602275655,
#    'NDCG5': 0.6164336326286644,
#    'NDCG10': 0.400023248309252,
#    'NDCG20': 0.3283336640176967,
#    'P1': 1.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.6,
#    'P10': 0.3,
#    'P20': 0.25,
#    'MRR100': 1.0},
#   0.5724911458465184),
#  ('do you want to know more about obamas parents',
#   'yes i only want to find the biographical information on barack obamas mother right now',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.46927872602275655,
#    'NDCG5': 0.6164336326286644,
#    'NDCG10': 0.46627747176364104,
#    'NDCG20': 0.3705652971134711,
#    'P1': 1.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.6,
#    'P10': 0.4,
#    'P20': 0.3,
#    'MRR100': 1.0},
#   0.5959898600783515),
#  ('how many generations would you like me to list from president obamas family tree',
#   'i dont want his family tree i just want biographical information on his mother',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.5307212739772434,
#    'NDCG5': 0.5147714448836773,
#    'NDCG10': 0.3340514446642156,
#    'NDCG20': 0.28695561771458516,
#    'P1': 0.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.3,
#    'P20': 0.25,
#    'MRR100': 0.5},
#   0.3621060407187625),
#  ('what would you like to know about obamas heritage',
#   'i would like to know information about obamas mother',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.5307212739772434,
#    'NDCG5': 0.5147714448836773,
#    'NDCG10': 0.4003056681186047,
#    'NDCG20': 0.2947004955957285,
#    'P1': 0.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.4,
#    'P20': 0.25,
#    'MRR100': 0.5},
#   0.37792414084017456),
#  ('which family members of obama are you interested in learning more about',
#   'i would like to learn about his entire family tree',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.46927872602275655,
#    'NDCG5': 0.3391602052736161,
#    'NDCG10': 0.2200917662980802,
#    'NDCG20': 0.2505963987330619,
#    'P1': 1.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.2,
#    'MRR100': 1.0},
#   0.4647691299691681),
#  ('which specific details would you like to learn about obamas heritage',
#   'i want to know about obamas mother',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.5307212739772434,
#    'NDCG5': 0.5147714448836773,
#    'NDCG10': 0.40348266660099286,
#    'NDCG20': 0.3316441474267896,
#    'P1': 0.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.4,
#    'P20': 0.3,
#    'MRR100': 0.5},
#   0.3861169272323064),
#  ('would you like to hear about president obamas family tree',
#   'i want information on his mother',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.5307212739772434,
#    'NDCG5': 0.5147714448836773,
#    'NDCG10': 0.4003056681186047,
#    'NDCG20': 0.3285159285412112,
#    'P1': 0.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.4,
#    'P20': 0.3,
#    'MRR100': 0.5},
#   0.3855437256534003),
#  ('are you going to purchase anything there',
#   'i dont know yet i just want general info about fickle creek farm',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.02614843371881735,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.058823529411764705},
#   0.012270178466416553),
#  ('are you looking for a place which sales products from fickle creek farm',
#   'just general information about the farm',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.028638519325045464,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.07692307692307693},
#   0.014141963295283853),
#  ('are you looking for information about staying at fickle creek farm',
#   'no i am looking for more general information',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0847890501964241,
#    'NDCG10': 0.06452577150984495,
#    'NDCG20': 0.046959683098172375,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.25},
#   0.07238859134585832),
#  ('are you looking for specific information regarding fickle creek farm',
#   'im looking for general information',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.027259251878163412,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.06666666666666667},
#   0.013084174413166371),
#  ('do you want the history of fickle creek farm',
#   'yes i would like the history of fickle creek farm',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.037037037037037035},
#   0.003367003367003367),
#  ('do you want to know the animal population at fickle creek farm',
#   'yes along with other general information',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.026675962998919795,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.0625},
#   0.012652360272629072),
#  ('do you want to know the location of fickle creek farm',
#   'yes along with other general information',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.025668283455303767,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.05555555555555555},
#   0.01192943991007812),
#  ('would you like to know where fickle creek farm is on a map',
#   'i just need general information about fickle creek',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.02614843371881735,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.058823529411764705},
#   0.012270178466416553),
#  ('are you going to purchase anything there',
#   'i am not sure',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.03571428571428571},
#   0.0032467532467532465),
#  ('are you looking for a place which sales products from fickle creek farm',
#   'no i want the physical address of fickle creek farm',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.05214426484655789,
#    'NDCG20': 0.040678987574421455,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.1},
#   0.03116575022008903),
#  ('are you looking for information about staying at fickle creek farm',
#   'no only its location and travel directions',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.20151514190050246,
#    'NDCG5': 0.1597913855951283,
#    'NDCG10': 0.11381311447980799,
#    'NDCG20': 0.08878833143691228,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.5},
#   0.1588401187950622),
#  ('are you looking for specific information regarding fickle creek farm',
#   'yes i am looking for its location and directions on how to get there',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.06425604298318155,
#    'NDCG20': 0.05012767524455527,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.16666666666666666},
#   0.03918639862676396),
#  ('do you want the history of fickle creek farm',
#   'no i want to know where fickle creek farm is and how i get there',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.03571428571428571},
#   0.0032467532467532465),
#  ('do you want to know the animal population at fickle creek farm',
#   'no i need to know how to get there',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.03374789133627879,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.058823529411764705},
#   0.012961038249822138),
#  ('do you want to know the location of fickle creek farm',
#   'i would like to know where fickle creek farm is and also hoe to ge there',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.03312819613417263,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.05555555555555555},
#   0.01260761378997529),
#  ('would you like to know where fickle creek farm is on a map',
#   'yes and i also need directions on how to get there',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.06425604298318155,
#    'NDCG20': 0.05012767524455527,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.16666666666666666},
#   0.03918639862676396),
#  ('are you going to purchase anything there',
#   'no i just need to know what food is grown or raised on the farms of fickle creek farm',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for a place which sales products from fickle creek farm',
#   'no i am interested in the type of products they grow or raise there',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for information about staying at fickle creek farm',
#   'no',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for specific information regarding fickle creek farm',
#   'yes what products do they grow there',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want the history of fickle creek farm',
#   'no i want to know what products they grow and raise at fickle creek farm',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want to know the animal population at fickle creek farm',
#   'no i want to know what products they grow or raise there',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want to know the location of fickle creek farm',
#   'no i want to know products that they grow or raise there',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like to know where fickle creek farm is on a map',
#   'i would like to know what the make',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you going to purchase anything there',
#   'i dont know i would like to see what they have first',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for a place which sales products from fickle creek farm',
#   'yes thats what i want',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for information about staying at fickle creek farm',
#   'i would like to by produce from fickle creek farm',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for specific information regarding fickle creek farm',
#   'yes where to buy thier products',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want the history of fickle creek farm',
#   'i want to buy something from them',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want to know the animal population at fickle creek farm',
#   'no i want to know where to buy their products',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want to know the location of fickle creek farm',
#   'no i want ot find out where can i purchase fickle creek farm products',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like to know where fickle creek farm is on a map',
#   'no i would like to know where i can buy products from fickle creek farm not where it is',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you going to purchase anything there',
#   'not sure i just need information about staying there',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.09404673201358825,
#    'NDCG10': 0.0697509626594255,
#    'NDCG20': 0.061645698295599315,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.25},
#   0.0750403084516921),
#  ('are you looking for a place which sales products from fickle creek farm',
#   'no i am looking for info on the bed and breakfast at fickle creek farms',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.16771752171325524,
#    'NDCG5': 0.13777597210996176,
#    'NDCG10': 0.10218331334064325,
#    'NDCG20': 0.09030931566921925,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.5},
#   0.15284722328785574),
#  ('are you looking for information about staying at fickle creek farm',
#   'yes i am looking for information about staying at fickle creek farm',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.16771752171325524,
#    'NDCG5': 0.13777597210996176,
#    'NDCG10': 0.10218331334064325,
#    'NDCG20': 0.09030931566921925,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.5},
#   0.15284722328785574),
#  ('are you looking for specific information regarding fickle creek farm',
#   'yes i want information about staying there',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.08447695052975515,
#    'NDCG10': 0.06265341172228864,
#    'NDCG20': 0.055372903383151414,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.2},
#   0.06840938778501776),
#  ('do you want the history of fickle creek farm',
#   'no i need information about its bed and breakfast',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.26582598262939583,
#    'NDCG5': 0.21836974929469327,
#    'NDCG10': 0.16195671984435941,
#    'NDCG20': 0.14313687880150205,
#    'P1': 1.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 1.0},
#   0.3611475149002985),
#  ('do you want to know the animal population at fickle creek farm',
#   'no i would like to know about staying at the bed and breakfast at fickle creek farm',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.26582598262939583,
#    'NDCG5': 0.21836974929469327,
#    'NDCG10': 0.16195671984435941,
#    'NDCG20': 0.14313687880150205,
#    'P1': 1.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 1.0},
#   0.3611475149002985),
#  ('do you want to know the location of fickle creek farm',
#   'i want information about staying at fickle creek farms bed and breakfast',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.16771752171325524,
#    'NDCG5': 0.13777597210996176,
#    'NDCG10': 0.10218331334064325,
#    'NDCG20': 0.09030931566921925,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.5},
#   0.15284722328785574),
#  ('would you like to know where fickle creek farm is on a map',
#   'no i would like information about staying at the bed and breakfast at fickle creek farm',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.16771752171325524,
#    'NDCG5': 0.13777597210996176,
#    'NDCG10': 0.10218331334064325,
#    'NDCG20': 0.09030931566921925,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.5},
#   0.15284722328785574),
#  ('are you interested in the human services department',
#   'no i am looking for doctors or hospitals in sonoma county california',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.10907458963273321,
#    'NDCG10': 0.18674035904412142,
#    'NDCG20': 0.2608167783313433,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.2,
#    'P10': 0.3,
#    'P20': 0.35,
#    'MRR100': 0.25},
#   0.15060288427347254),
#  ('is this for an emergancy',
#   'no',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.1596969716198995,
#    'NDCG5': 0.12663167705327652,
#    'NDCG10': 0.09019475927038985,
#    'NDCG20': 0.062186978873009044,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.3333333333333333},
#   0.13230700486211286),
#  ('would you like the different services that are provided',
#   'yes please',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.5209090851403014,
#    'NDCG5': 0.5110303792074371,
#    'NDCG10': 0.5405169720071084,
#    'NDCG20': 0.49754612542197935,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.6,
#    'P20': 0.5,
#    'MRR100': 1.0},
#   0.630606293494863),
#  ('are you looking for contact information',
#   'no i want to know about available medical services in sonoma county',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.47909091485969857,
#    'NDCG5': 0.3798950311598296,
#    'NDCG10': 0.43393775588179,
#    'NDCG20': 0.36084991847640857,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.4,
#    'P10': 0.5,
#    'P20': 0.35,
#    'MRR100': 1.0},
#   0.5518582079131267),
#  ('are you looking for employment with sonoma country medical',
#   'no i want to know the services available',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.20151514190050246,
#    'NDCG5': 0.25776702510088406,
#    'NDCG10': 0.24785334910617754,
#    'NDCG20': 0.20355530502324773,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.4,
#    'P10': 0.3,
#    'P20': 0.2,
#    'MRR100': 0.5},
#   0.24036583222401323),
#  ('are you looking for specific program information',
#   'no i want to know what medical services are available there',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.6806060567602009,
#    'NDCG5': 0.6376620562607137,
#    'NDCG10': 0.4541815839341656,
#    'NDCG20': 0.47279847997578567,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 0.8,
#    'P10': 0.4,
#    'P20': 0.45,
#    'MRR100': 1.0},
#   0.6722952888118969),
#  ('do you need addresses',
#   'no',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.5209090851403014,
#    'NDCG5': 0.41305473970168133,
#    'NDCG10': 0.35845867600376924,
#    'NDCG20': 0.2782415753321258,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.4,
#    'P10': 0.3,
#    'P20': 0.2,
#    'MRR100': 1.0},
#   0.5124846129858678),
#  ('do you need any specific information on health insurance',
#   'no i want to know what services are provided',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.5209090851403014,
#    'NDCG5': 0.41305473970168133,
#    'NDCG10': 0.3511091902604917,
#    'NDCG20': 0.33597962194391834,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.4,
#    'P10': 0.3,
#    'P20': 0.3,
#    'MRR100': 1.0},
#   0.5261563003375508),
#  ('do you want information on the differenct services that are provided',
#   'yes',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.6806060567602009,
#    'NDCG5': 0.5396864167549579,
#    'NDCG10': 0.4445272318045708,
#    'NDCG20': 0.40067856084295295,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 0.6,
#    'P10': 0.4,
#    'P20': 0.35,
#    'MRR100': 1.0},
#   0.6286816605602439),
#  ('how soon is this needed',
#   'immediately i need any information on what are the options having to do with all medical services in sonoma',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.47909091485969857,
#    'NDCG5': 0.4889696207925628,
#    'NDCG10': 0.46531021152232627,
#    'NDCG20': 0.35265399838853845,
#    'P1': 1.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.6,
#    'P10': 0.5,
#    'P20': 0.3,
#    'MRR100': 1.0},
#   0.5775174011117993),
#  ('is there a specific program you are looking for',
#   'no i want to know about the services they provide',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.6806060567602009,
#    'NDCG5': 0.6376620562607137,
#    'NDCG10': 0.5143114234477588,
#    'NDCG20': 0.5114608373613816,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 0.8,
#    'P10': 0.5,
#    'P20': 0.5,
#    'MRR100': 1.0},
#   0.6949127612572777),
#  ('are you interested in the human services department',
#   'no i just need the homepage of county medical services program sonoma california',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('is this for an emergancy',
#   'no i am trying to locate the home webpage for the county medical services program of sonoma county california',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like the different services that are provided',
#   'i dont know',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for contact information',
#   'i would like the general homepage',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for employment with sonoma country medical',
#   'no',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for specific program information',
#   'no just the front page',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you need addresses',
#   'no just the website',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you need any specific information on health insurance',
#   'yes the homepage of county medical services program of sonoma county',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want information on the differenct services that are provided',
#   'give me the homepage of the cmsp',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('how soon is this needed',
#   'as soon as possible',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('is there a specific program you are looking for',
#   'no i want to see the website for the county medical services program',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you interested in the human services department',
#   'possibly specifically i need information on health care coverage for low income residents in sonoma county',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.16771752171325524,
#    'NDCG5': 0.22225292263971688,
#    'NDCG10': 0.16483672506293187,
#    'NDCG20': 0.1561355504626607,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.4,
#    'P10': 0.2,
#    'P20': 0.15,
#    'MRR100': 0.5},
#   0.20857055029199073),
#  ('is this for an emergancy',
#   'no',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like the different services that are provided',
#   'no im looking for coverage for lowincome people',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.13291299131469791,
#    'NDCG5': 0.10918487464734664,
#    'NDCG10': 0.08097835992217971,
#    'NDCG20': 0.06268224266360316,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.3333333333333333},
#   0.12749319411040855),
#  ('are you looking for contact information',
#   'maybe i want information about healthcare services for lowincome residents of this county',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.05769014760900126,
#    'NDCG20': 0.07366234129035093,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.1,
#    'P20': 0.1,
#    'MRR100': 0.16666666666666666},
#   0.045274468687819897),
#  ('are you looking for employment with sonoma country medical',
#   'no id like to learn more about lowincome health care coverage in sonoma county ca',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.051091656670321624,
#    'NDCG20': 0.07247501569842124,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.1,
#    'P20': 0.1,
#    'MRR100': 0.125},
#   0.04077878839715844),
#  ('are you looking for specific program information',
#   'yes coverage for lowincome people',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.13291299131469791,
#    'NDCG5': 0.10918487464734664,
#    'NDCG10': 0.12779435101500428,
#    'NDCG20': 0.1279273164498453,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.2,
#    'P20': 0.15,
#    'MRR100': 0.3333333333333333},
#   0.15586238182668732),
#  ('do you need addresses',
#   'no just information',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.05769014760900126,
#    'NDCG20': 0.04465573068164908,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.16666666666666666},
#   0.038092049541574274),
#  ('do you need any specific information on health insurance',
#   'yes low income health insurance in sonoma county ca',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.13291299131469791,
#    'NDCG5': 0.2032316066609349,
#    'NDCG10': 0.1507293225816052,
#    'NDCG20': 0.15164332652617554,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.4,
#    'P10': 0.2,
#    'P20': 0.15,
#    'MRR100': 0.3333333333333333},
#   0.18683490125000726),
#  ('do you want information on the differenct services that are provided',
#   'yes',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.03134112133180158,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.06666666666666667},
#   0.013455253454406206),
#  ('how soon is this needed',
#   'i dont know',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.022222222222222223},
#   0.00202020202020202),
#  ('is there a specific program you are looking for',
#   'yes coverage for lowincome people',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.16771752171325524,
#    'NDCG5': 0.13777597210996176,
#    'NDCG10': 0.10218331334064325,
#    'NDCG20': 0.10976667313178029,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.1,
#    'MRR100': 0.5},
#   0.1591615285117249),
#  ('are you interested in learning more about ralph owen brewseter',
#   'yes and his biography',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.5,
#    'NDCG5': 0.6386367136775241,
#    'NDCG10': 0.7336895592401868,
#    'NDCG20': 0.6833180416071138,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 1.0,
#    'P20': 0.9,
#    'MRR100': 1.0},
#   0.8141494831386205),
#  ('would you like to know the political positions ralph owen brewster held',
#   'yes',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.863664922155261,
#    'NDCG20': 0.724493537326701,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 1.0,
#    'P20': 0.75,
#    'MRR100': 1.0},
#   0.9398325872256329),
#  ('would you like to know what movie star portrayed brewster in the movie the aviator and what award the movie star was nominated for the performance',
#   'no',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.8318545280557852,
#    'NDCG20': 0.6588891028779814,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.9,
#    'P20': 0.6,
#    'MRR100': 1.0},
#   0.9082494209939788),
#  ('would you like to know what political party ralph owen brewster was affiliated with',
#   'yes and other information about him',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.863664922155261,
#    'NDCG20': 0.724493537326701,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 1.0,
#    'P20': 0.75,
#    'MRR100': 1.0},
#   0.9398325872256329),
#  ('how old is ralph owen brewseter',
#   'yes',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.11731968150568914,
#    'NDCG5': 0.22342676499592815,
#    'NDCG10': 0.49605710724825935,
#    'NDCG20': 0.536332527505982,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.6,
#    'P10': 0.8,
#    'P20': 0.8,
#    'MRR100': 0.3333333333333333},
#   0.38543661344750224),
#  ('may i provide you with information regarding when ralph owen brewster died and cause of death',
#   'yes please also include general biographical info too',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.863664922155261,
#    'NDCG20': 0.7230216473893986,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 1.0,
#    'P20': 0.75,
#    'MRR100': 1.0},
#   0.9396987790495146),
#  ('may i tell you about brewsters parents where and when he was born',
#   'yes i am interested in all biographical information about ralph owen brewster',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.863664922155261,
#    'NDCG20': 0.7230216473893986,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 1.0,
#    'P20': 0.75,
#    'MRR100': 1.0},
#   0.9396987790495146),
#  ('what is ralph owen brewser famous for',
#   'yes that is part fo what im looking for',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.2653606369886217,
#    'NDCG5': 0.39602243611936283,
#    'NDCG10': 0.6080598880058472,
#    'NDCG20': 0.6133265221062811,
#    'P1': 0.0,
#    'P3': 0.6666666666666666,
#    'P5': 0.8,
#    'P10': 0.9,
#    'P20': 0.9,
#    'MRR100': 0.5},
#   0.5135851045351618),
#  ('what is ralph owen brewsters background',
#   'i dont know',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.5,
#    'NDCG5': 0.6386367136775241,
#    'NDCG10': 0.7336895592401868,
#    'NDCG20': 0.6109065039040713,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 1.0,
#    'P20': 0.7,
#    'MRR100': 1.0},
#   0.7893847978928893),
#  ('what is ralph owen brewsters education',
#   'please answeers this and give me more information',
#   {'NDCG1': 1.0,
#    'NDCG3': 0.8826803184943108,
#    'NDCG5': 0.7765732350040717,
#    'NDCG10': 0.8232009233204183,
#    'NDCG20': 0.6936649934383136,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 1.0,
#    'P20': 0.75,
#    'MRR100': 1.0},
#   0.9023744972961013),
#  ('who is ralph owen brewster',
#   'i am not sure so i want to know',
#   {'NDCG1': 0.5,
#    'NDCG3': 0.5,
#    'NDCG5': 0.6386367136775241,
#    'NDCG10': 0.6960687314028854,
#    'NDCG20': 0.5999407006219383,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.9,
#    'P20': 0.7,
#    'MRR100': 1.0},
#   0.7758769223365771),
#  ('would you like to know about brewsters college education degree and work history',
#   'i want all biographical information available for ralph owen brewster',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.863664922155261,
#    'NDCG20': 0.759972081328133,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 1.0,
#    'P20': 0.85,
#    'MRR100': 1.0},
#   0.9521488184984903),
#  ('are you interested in learning more about ralph owen brewseter',
#   'yes and what offices did he hold',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.7591402384099978,
#    'NDCG20': 0.7381984625467306,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.7,
#    'P20': 0.8,
#    'MRR100': 1.0},
#   0.908848972814248),
#  ('would you like to know the political positions ralph owen brewster held',
#   'yes please give me a list of the elected offices held by ralph owen brewster',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.7591402384099978,
#    'NDCG20': 0.7579352554712488,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.7,
#    'P20': 0.85,
#    'MRR100': 1.0},
#   0.9151886812619314),
#  ('would you like to know what movie star portrayed brewster in the movie the aviator and what award the movie star was nominated for the performance',
#   'no',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.8318545280557852,
#    'NDCG20': 0.6541275731822892,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.9,
#    'P20': 0.55,
#    'MRR100': 1.0},
#   0.9032711001125523),
#  ('would you like to know what political party ralph owen brewster was affiliated with',
#   'no i need to know what elected offices he held',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.7591402384099978,
#    'NDCG20': 0.7579352554712488,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.7,
#    'P20': 0.85,
#    'MRR100': 1.0},
#   0.9151886812619314),
#  ('how old is ralph owen brewseter',
#   'no i want to know what offices he held',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.727329844310522,
#    'NDCG20': 0.7346154108904794,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.6,
#    'P20': 0.8,
#    'MRR100': 1.0},
#   0.8965404777455457),
#  ('may i provide you with information regarding when ralph owen brewster died and cause of death',
#   'no i want to know about his office positions',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.7591402384099978,
#    'NDCG20': 0.6996631758348826,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.7,
#    'P20': 0.7,
#    'MRR100': 1.0},
#   0.8962548558404436),
#  ('may i tell you about brewsters parents where and when he was born',
#   'no thanks i want to know about his elected offices',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.7591402384099978,
#    'NDCG20': 0.7579352554712488,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.7,
#    'P20': 0.85,
#    'MRR100': 1.0},
#   0.9151886812619314),
#  ('what is ralph owen brewser famous for',
#   'i am looking for the elected offices of ralph owen',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.8318545280557852,
#    'NDCG20': 0.7457481451683903,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.9,
#    'P20': 0.8,
#    'MRR100': 1.0},
#   0.9343275157476524),
#  ('what is ralph owen brewsters background',
#   'no what offices did he hold',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.7591402384099978,
#    'NDCG20': 0.6968412776074461,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.7,
#    'P20': 0.7,
#    'MRR100': 1.0},
#   0.8959983196379493),
#  ('what is ralph owen brewsters education',
#   'no i want to know the elected offices that he held',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.7591402384099978,
#    'NDCG20': 0.7579352554712488,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.7,
#    'P20': 0.85,
#    'MRR100': 1.0},
#   0.9151886812619314),
#  ('who is ralph owen brewster',
#   'he was an elected official',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.7938558493783865,
#    'NDCG20': 0.7438291142773775,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.8,
#    'P20': 0.8,
#    'MRR100': 1.0},
#   0.9216077239687059),
#  ('would you like to know about brewsters college education degree and work history',
#   'yes i would like to know what elected offices he held',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.7591402384099978,
#    'NDCG20': 0.7188519736634731,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.7,
#    'P20': 0.75,
#    'MRR100': 1.0},
#   0.9025447465521338),
#  ('are you interested in learning more about ralph owen brewseter',
#   'yes especially about his relationship with howard hughes',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.8249700383693802,
#    'NDCG20': 0.7687597853970727,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.8,
#    'P20': 0.55,
#    'MRR100': 1.0},
#   0.903975438524223),
#  ('would you like to know the political positions ralph owen brewster held',
#   'no',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.7512266604370578,
#    'NDCG20': 0.7362526217245159,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.6,
#    'P20': 0.45,
#    'MRR100': 1.0},
#   0.8670435711055976),
#  ('would you like to know what movie star portrayed brewster in the movie the aviator and what award the movie star was nominated for the performance',
#   'no i need to know the relationship he had with howard hughs',
#   {'NDCG1': 1.0,
#    'NDCG3': 1.0,
#    'NDCG5': 1.0,
#    'NDCG10': 0.8249700383693802,
#    'NDCG20': 0.7725405801997123,
#    'P1': 1.0,
#    'P3': 1.0,
#    'P5': 1.0,
#    'P10': 0.8,
#    'P20': 0.55,
#    'MRR100': 1.0},
#   0.9043191471426449),
#  ('would you like to know what political party ralph owen brewster was affiliated with',
# ...
#   'this is not related to my search',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like to see google maps homepage',
#   'no where can i find satellite maps and live satellite photos',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.015384615384615385},
#   0.0013986013986013986),
#  ('are you interested in satellite maps',
#   'yes i am',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.041666666666666664},
#   0.0037878787878787876),
#  ('are you looking for a world atlas',
#   'no i am looking for satellite maps',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.015384615384615385},
#   0.0013986013986013986),
#  ('are you on a road trip',
#   'thats irrelevant but i need sources for satellite maps and live photos',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.014492753623188406},
#   0.0013175230566534915),
#  ('are you traveling',
#   'no right now i am looking for live satellite maps and photos',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.03571428571428571},
#   0.0032467532467532465),
#  ('do you have map apps on your phone',
#   'i am interested in live satellite photos and satellite map sources',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.018518518518518517},
#   0.0016835016835016834),
#  ('do you need traveling assistance or direction',
#   'no',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you study road maps',
#   'none of your business find me satellite maps both the sources and live feeds',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.011627906976744186},
#   0.0010570824524312897),
#  ('do you want a map of your local area',
#   'yes',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.019230769230769232},
#   0.0017482517482517483),
#  ('do you want a map with driving directions',
#   'no i want satellite maps',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.025},
#   0.002272727272727273),
#  ('are you interested in cartography',
#   'no i want to use a online world atlas',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want a tourist map',
#   'no an online world atlas',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want themed maps',
#   'no',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('what place do you want a map of',
#   'the entire world',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like a map with services or sites of interest listed',
#   'maybe just show me an online world atlas with general features for now',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like to see google maps homepage',
#   'no',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you interested in satellite maps',
#   'no i want an online world atlas',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for a world atlas',
#   'yes i am looking for an online world atlas',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you on a road trip',
#   'i need an online world atlas',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you traveling',
#   'i need to see a world atlas online',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you have map apps on your phone',
#   'yes i have map apps on my phone which i mostly used for travelling',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you need traveling assistance or direction',
#   'i do not know',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you study road maps',
#   'i want to get a world atlas online',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want a map of your local area',
#   'i need a world atlas',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want a map with driving directions',
#   'no i need a world atlas online',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for a specific web page',
#   'possibly',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.01694915254237288},
#   0.0015408320493066256),
#  ('would you like to know the history of the equal opportunity employer act',
#   'yes',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like to know what the equal opportunity employer act is',
#   'yes i am specifically interested in the definition of the term equal opportunity employer',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like to see how to meet the legal requirement to be an equal opportunity employer',
#   'this doesnt answer my question',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('would you like to see jobs around you that are equal opportunity employers',
#   'no id like to know what it means',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.03225806451612903},
#   0.002932551319648094),
#  ('would you like to see the legal definition of equal opportunity employer',
#   'i would like to know the legal definition of the phrase equal opportunity employer',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('are you looking for anything specific in terms of equal opportunity discrimination',
#   'no i just want to know what the phrase means',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.03571428571428571},
#   0.0032467532467532465),
#  ('are you looking for specific information regarding an equal opportunity employer',
#   'just want a general definition nothing specific',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you need information about a specific employer',
#   'no i need to know the definition of equal oppurtunity employer',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.0},
#   0.0),
#  ('do you want to know what being an equal opportunity employer means',
#   'yes',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.058353831264085644,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.0625},
#   0.01553216647855324),
#  ('what do you need to know about equal opportunity employment',
#   'what it means',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.043478260869565216},
#   0.003952569169960474),
#  ('what information would you like in regards to an equal opportunity employer',
#   'i want the definition of an equal opportunity employer',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.010638297872340425},
#   0.0009671179883945841),
#  ('would you like to know if you are eligible for equal opportunity employment',
#   'no i need to know the meaning of the phrase equal opportunity employer',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.034482758620689655},
#   0.003134796238244514),
#  ('would you like to know if your company adheres to equal opportunity employment',
#   'no i want a definition of equal opportunity employer',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.10272459231693526,
#    'NDCG10': 0.10272459231693526,
#    'NDCG20': 0.10272459231693526,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.25},
#   0.08256125245007326),
#  ('are you looking for a specific web page',
#   'yes i would like to know who to contact about being discriminated against by an equal opportunity employer',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.04},
#   0.0036363636363636364),
#  ('would you like to know the history of the equal opportunity employer act',
#   'no i want information on who to contact regarding employment discrimination',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.024166416467776217,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.06666666666666667},
#   0.012803007557676625),
#  ('would you like to know what the equal opportunity employer act is',
#   'no',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.022007896189331005,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.05},
#   0.01109162692630282),
#  ('would you like to see how to meet the legal requirement to be an equal opportunity employer',
#   'no i am looking for information on discrimination by an equal opportunity employer',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.022007896189331005,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.05},
#   0.01109162692630282),
#  ('would you like to see jobs around you that are equal opportunity employers',
#   'no i think i am being discriminated against',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.037037037037037035},
#   0.003367003367003367),
#  ('would you like to see the legal definition of equal opportunity employer',
#   'no i need to find whom to contact if i am being discriminated against',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.02612275114149533,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.05,
#    'MRR100': 0.08333333333333333},
#   0.01449600767952988),
#  ('are you looking for anything specific in terms of equal opportunity discrimination',
#   'yes im trying to find out who to contact if i think im being discriminated against',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.045454545454545456},
#   0.004132231404958678),
#  ('are you looking for specific information regarding an equal opportunity employer',
#   'yes i am looking for how to report a violation of the equal opportunity employer act',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.03683186995726718,
#    'NDCG20': 0.027942643915933905,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.1},
#   0.028615864897563736),
#  ('do you need information about a specific employer',
#   'i need to know whom to contact if im being discriminated against',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.04538697066857469,
#    'NDCG20': 0.034433004929870205,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.16666666666666666},
#   0.03604424020591923),
#  ('do you want to know what being an equal opportunity employer means',
#   'no i need to know who to contact if i think im being discriminated against',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.0,
#    'NDCG5': 0.0,
#    'NDCG10': 0.0,
#    'NDCG20': 0.0,
#    'P1': 0.0,
#    'P3': 0.0,
#    'P5': 0.0,
#    'P10': 0.0,
#    'P20': 0.0,
#    'MRR100': 0.030303030303030304},
#   0.0027548209366391185),
#  ('what do you need to know about equal opportunity employment',
#   'who to contact about discrimination',
#   {'NDCG1': 0.0,
#    'NDCG3': 0.14804095548293264,
#    'NDCG5': 0.10699313236726377,
#    'NDCG10': 0.08039138809008574,
#    'NDCG20': 0.06098924474687704,
#    'P1': 0.0,
#    'P3': 0.3333333333333333,
#    'P5': 0.2,
#    'P10': 0.1,
#    'P20': 0.05,
#    'MRR100': 0.5},
#   0.14361345945640844),
#  ...]
